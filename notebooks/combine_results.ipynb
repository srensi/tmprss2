# %% [markdown]
# # Combine Results
# Author: Doug Klink (dklink@stanford.edu)
#
# Herein we combine the results generated by KNN, Random Forest, and SVM.  We create a final output table which has the score each gave to each compound (or NaN if compound unscored by one method), and a "combined_score" column which is the weighted average of the three methods' scores, the weights being the inverse of the RMSE each method achieved in its regression validation.

# %%
import pandas as pd
import numpy as np

# %%
knn = pd.read_csv('../results/knn_results.csv', index_col=0).reset_index(drop=True)
knn.head(10)
# Out:
#      source                                               name  \
# 0   reframe                                         NAFAMOSTAT
# 1     broad                                           CTS21166
# 2  drugbank                                         IPAMORELIN
# 3  drugbank  1-[(4S)-4-AMINO-5-(1,3-BENZOTHIAZOL-2-YL)-5-OX...
# 4  drugbank  L-N(OMEGA)-NITROARGININE-(4R)-AMINO-L-PROLINE ...
# 5  drugbank                                          RWJ-56423
# 6  drugbank                                     ANGIOTENSIN II
# 7  drugbank                                        THYMOPENTIN
# 8  drugbank                                          BIO-11006
# 9  drugbank                                        PLECANATIDE
#
#    predicted_acvalue(log10)      RMSE
# 0                 -4.573860  0.716535
# 1                 -3.261067  0.716535
# 2                 -3.258770  0.716535
# 3                 -3.230251  0.716535
# 4                 -3.226611  0.716535
# 5                 -3.215892  0.716535
# 6                 -3.199554  0.716535
# 7                 -3.121986  0.716535
# 8                 -3.066794  0.716535
# 9                 -3.064554  0.716535

# %%
rf = pd.read_csv('../results/random_forest_results.csv', index_col=0).reset_index(drop=True)
rf['predicted_activity(log10)'] = -rf['predicted_activity(log10)']
rf.head(10)
# Out:
#                                                 name  \
# 0                                         NAFAMOSTAT
# 1                                          RWJ-51084
# 2                                          RWJ-56423
# 3                                         PATAMOSTAT
# 4                                           CAMOSTAT
# 5  1-[(4S)-4-AMINO-5-(1,3-BENZOTHIAZOL-2-YL)-5-OX...
# 6                                          RWJ-58643
# 7                                            PGL5001
# 8                                         BMS-605339
# 9                                SEPIMOSTAT MESILATE
#
#                                               smiles  \
# 0  C1=CC(=CC=C1C(=O)OC2=CC3=C(C=C2)C=C(C=C3)C(=N)...
# 1  [H]N([H])C(=NCCC[C@H](N([H])C(=O)C1CCCC1)C(=O)...
# 2  [H]N([H])C(=NCCC[C@H](N([H])C(=O)[C@@H]1C[C@@H...
# 3  C1CC(=O)N(C1=O)CCSC2=CC=C(C=C2)OC(=O)C3=CC=C(C...
# 4  CN(C)C(=O)COC(=O)CC1=CC=C(C=C1)OC(=O)C2=CC=C(C...
# 5          N[C@@H](CCCNC(N)=N)C(=O)C1=NC2=CC=CC=C2S1
# 6  CC(=O)N1C[C@H](O)C[C@H]1C(=O)NC(CCCNC(N)=N)C(=...
# 7  N#CC(c1nc2ccccc2s1)c1ccnc(OCc2ccc(CN3CCOCC3)cc...
# 8  CC(C)(C)[C@@H](C(=O)N1C[C@@H](C[C@H]1C(=O)N[C@...
# 9  [H]/N=C(/C1=CC=C2C=C(C=CC2=C1)OC(=O)C3=CC=C(C=...
#
#    predicted_activity(log10)      RMSE
# 0                  -2.797827  0.348182
# 1                  -2.499190  0.348182
# 2                  -2.365654  0.348182
# 3                  -2.248543  0.348182
# 4                  -2.212964  0.348182
# 5                  -1.974841  0.348182
# 6                  -1.959521  0.348182
# 7                  -1.639983  0.348182
# 8                  -1.638343  0.348182
# 9                  -1.637788  0.348182

# %%
svm = pd.read_csv('../results/svm_screening_results_no_duplicate_names.csv', index_col=0).reset_index(drop=True)
svm['name'] = svm.name.str.upper()
svm.head(10)
# Out:
#      source                          name  pred_value      RMSE
# 0   reframe                    NAFAMOSTAT   -4.573851  0.750939
# 1     broad                   SUBSTANCE-P   -3.270026  0.750939
# 2   reframe                      CAMOSTAT   -3.063672  0.750939
# 3     broad  [SAR9,MET(O2)11]-SUBSTANCE-P   -2.878899  0.750939
# 4  drugbank  SAR9, MET (O2)11-SUBSTANCE P   -2.878899  0.750939
# 5   reframe                     RWJ-58643   -2.231559  0.750939
# 6   reframe           SEPIMOSTAT MESILATE   -2.119949  0.750939
# 7  drugbank                     RWJ-56423   -2.051680  0.750939
# 8     broad                    TELAPREVIR   -2.013527  0.750939
# 9   reframe                   ATECEGATRAN   -1.981752  0.750939

# %%
knn_RMSE = knn['RMSE'][0]
rf_RMSE = rf['RMSE'][0]
svm_RMSE = svm['RMSE'][0]
print(f'Method          RMSE     Weight (1/RMSE)')
print(f'knn            {knn_RMSE: .2f}    {1/knn_RMSE: .2f}')
print(f'random forest  {rf_RMSE: .2f}    {1/rf_RMSE: .2f}')
print(f'svm            {svm_RMSE: .2f}    {1/svm_RMSE: .2f}')
# Out:
# Method          RMSE     Weight (1/RMSE)
# knn             0.72     1.40
# random forest   0.35     2.87
# svm             0.75     1.33

# %%
knn.drop(columns=['source', 'RMSE'], inplace=True)
rf.drop(columns=['smiles', 'RMSE'], inplace=True)
svm.drop(columns=['source', 'RMSE'], inplace=True)

# %%
knn = knn.rename(columns={'predicted_acvalue(log10)': 'knn_acvalue'})
rf = rf.rename(columns={'predicted_activity(log10)': 'random_forest_acvalue'})
svm = svm.rename(columns={'pred_value': 'svm_acvalue'})

# %%
combined = rf.merge(svm, on='name', how='outer').merge(knn, on='name', how='outer')

# %%
combined.head(10)
# Out:
#                                                 name  random_forest_acvalue  \
# 0                                         NAFAMOSTAT              -2.797827
# 1                                          RWJ-51084              -2.499190
# 2                                          RWJ-56423              -2.365654
# 3                                         PATAMOSTAT              -2.248543
# 4                                           CAMOSTAT              -2.212964
# 5  1-[(4S)-4-AMINO-5-(1,3-BENZOTHIAZOL-2-YL)-5-OX...              -1.974841
# 6                                          RWJ-58643              -1.959521
# 7                                            PGL5001              -1.639983
# 8                                         BMS-605339              -1.638343
# 9                                SEPIMOSTAT MESILATE              -1.637788
#
#    svm_acvalue  knn_acvalue
# 0    -4.573851    -4.573860
# 1    -1.887822    -3.003530
# 2    -2.051680    -3.215892
# 3          NaN          NaN
# 4    -3.063672          NaN
# 5          NaN    -3.230251
# 6    -2.231559    -2.847431
# 7          NaN          NaN
# 8          NaN          NaN
# 9    -2.119949          NaN

# %%
acvalue = np.array([combined.knn_acvalue, combined.svm_acvalue, combined.random_forest_acvalue]).T
weights = np.array([1/knn_RMSE, 1/svm_RMSE, 1/rf_RMSE]) * np.ones_like(acvalue)
weights[np.isnan(acvalue)] = 0
combined['combined_acvalue'] = np.nansum(acvalue*weights, axis=1) / np.sum(weights, axis=1)

# %%
combined.sort_values(by='combined_acvalue', inplace=True)
combined.reset_index(drop=True, inplace=True)
combined.to_csv('../results/combined_results.csv')

# %%
pd.set_option('display.max_rows', 50)
combined.head(50)
# Out:
#                                                  name  random_forest_acvalue  \
# 0                                          NAFAMOSTAT              -2.797827
# 1                                           RWJ-56423              -2.365654
# 2                                            CAMOSTAT              -2.212964
# 3                                           RWJ-51084              -2.499190
# 4   1-[(4S)-4-AMINO-5-(1,3-BENZOTHIAZOL-2-YL)-5-OX...              -1.974841
# 5                                          PATAMOSTAT              -2.248543
# 6                                           RWJ-58643              -1.959521
# 7                                 SEPIMOSTAT MESILATE              -1.637788
# 8                                         SUBSTANCE-P              -1.214972
# 9                                            U-75799E              -1.156762
# 10                                         EXAMORELIN              -1.125477
# 11                       [SAR9,MET(O2)11]-SUBSTANCE-P              -1.144704
# 12                       SAR9, MET (O2)11-SUBSTANCE P              -1.144704
# 13                        INDIUM IN-111 PENTETREOTIDE              -1.057353
# 14                                         DEPREOTIDE              -1.014655
# 15                                            PGL5001              -1.639983
# 16                                         BMS-605339              -1.638343
# 17                               DELTA-2-ALBOMYCIN A1              -1.139417
# 18  1-(5-CHLORO-2-METHOXYPHENYL)-3-{6-[2-(DIMETHYL...              -1.616776
# 19                                   AERUGINOSIN 98-B              -1.156905
# 20                                         CILUPREVIR              -1.611771
# 21                                        ORPHANIN-FQ              -0.950890
# 22                                          BIO-11006              -0.816413
# 23                                         SOVAPREVIR              -1.548875
# 24                            QUININE-ETHYL-CARBONATE              -1.534249
# 25                                            QUININE              -1.532766
# 26                                         IPAMORELIN              -0.677497
# 27                                       HYDROQUININE              -1.520954
# 28                              QUINIDINE BARBITURATE              -1.508156
# 29                                           BOMBESIN              -1.129983
# 30                                            MK-8831              -1.493149
# 31                                        GONADORELIN              -0.980204
# 32                                          SIPONIMOD              -1.463244
# 33                                          QUINIDINE              -1.462970
# 34                                     HYDROQUINIDINE              -1.445113
# 35                                           CTS21166              -0.538498
# 36  1,3-BIS-([[3-(4-{3-[3-NITRO-5-(GALACTOPYRANOSY...              -1.425049
# 37                                         CEFSULODIN              -1.422175
# 38                                                Y16              -1.408882
# 39                                  GOSERELIN-ACETATE              -1.044103
# 40  L-N(OMEGA)-NITROARGININE-(4R)-AMINO-L-PROLINE ...              -0.495212
# 41                                       ANTAGONIST-G              -0.890731
# 42                                          GOSERELIN              -1.112922
# 43  1,3-BIS-([3-[3-[3-(4-{3-[3-NITRO-5-(GALACTOPYR...              -1.372158
# 44                                     MODIMELANOTIDE              -1.166364
# 45                                        TRIPTORELIN              -1.121105
# 46                                         LEUPROLIDE              -1.119606
# 47                                        VASOPRESSIN              -0.944246
# 48                                         DESLORELIN              -1.081082
# 49                                            MK-2748              -1.348369
#
#     svm_acvalue  knn_acvalue  combined_acvalue
# 0     -4.573851    -4.573860         -3.662878
# 1     -2.051680    -3.215892         -2.502900
# 2     -3.063672          NaN         -2.482453
# 3     -1.887822    -3.003530         -2.479495
# 4           NaN    -3.230251         -2.385383
# 5           NaN          NaN         -2.248543
# 6     -2.231559    -2.847431         -2.245526
# 7     -2.119949          NaN         -1.790528
# 8     -3.270026    -1.560627         -1.789869
# 9           NaN    -2.929955         -1.736628
# 10          NaN    -2.927515         -1.714776
# 11    -2.878899    -1.672230         -1.688623
# 12    -2.878899    -1.672230         -1.688623
# 13          NaN    -2.905743         -1.661811
# 14          NaN    -2.937208         -1.643365
# 15          NaN          NaN         -1.639983
# 16          NaN          NaN         -1.638343
# 17          NaN    -2.626270         -1.625645
# 18          NaN          NaN         -1.616776
# 19          NaN    -2.555776         -1.614361
# 20          NaN          NaN         -1.611771
# 21          NaN    -2.892716         -1.585902
# 22          NaN    -3.066794         -1.552329
# 23          NaN          NaN         -1.548875
# 24          NaN          NaN         -1.534249
# 25          NaN          NaN         -1.532766
# 26          NaN    -3.258770         -1.521620
# 27          NaN          NaN         -1.520954
# 28          NaN          NaN         -1.508156
# 29          NaN    -2.260552         -1.499699
# 30          NaN          NaN         -1.493149
# 31    -1.594884    -2.406312         -1.481841
# 32          NaN          NaN         -1.463244
# 33          NaN          NaN         -1.462970
# 34          NaN          NaN         -1.445113
# 35          NaN    -3.261067         -1.428828
# 36          NaN          NaN         -1.425049
# 37          NaN          NaN         -1.422175
# 38          NaN          NaN         -1.408882
# 39    -1.312182    -2.220121         -1.400975
# 40          NaN    -3.226611         -1.388429
# 41    -1.588432    -2.211524         -1.385863
# 42    -0.538989    -2.701226         -1.372302
# 43          NaN          NaN         -1.372158
# 44    -1.447966    -1.688822         -1.363556
# 45    -1.026408    -2.177346         -1.361846
# 46    -1.000844    -2.173662         -1.354079
# 47    -1.845739    -1.718697         -1.351672
# 48    -1.063724    -2.177118         -1.350135
# 49          NaN          NaN         -1.348369
