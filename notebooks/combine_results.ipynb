# %% [markdown]
# # Combine Results
# Author: Doug Klink (dklink@stanford.edu)
#
# Herein we combine the results generated by KNN, Random Forest, and SVM.  We create a final output table which has the score each gave to each compound (or NaN if compound unscored by one method), and a "combined_score" column which is the weighted average of the three methods' scores, the weights being the inverse of the RMSE each method achieved in its regression validation.

# %%
import pandas as pd
import numpy as np

# %%
knn = pd.read_csv('../results/knn_results.csv', index_col=0).reset_index(drop=True)
knn.head(10)
# Out:
#      source                                               name  \
# 0   reframe                                         NAFAMOSTAT
# 1     broad                                           CTS21166
# 2  drugbank                                         IPAMORELIN
# 3  drugbank  1-[(4S)-4-AMINO-5-(1,3-BENZOTHIAZOL-2-YL)-5-OX...
# 4  drugbank  L-N(OMEGA)-NITROARGININE-(4R)-AMINO-L-PROLINE ...
# 5  drugbank                                          RWJ-56423
# 6  drugbank                                     ANGIOTENSIN II
# 7  drugbank                                        THYMOPENTIN
# 8  drugbank                                          BIO-11006
# 9  drugbank                                        PLECANATIDE
#
#    predicted_acvalue(log10)      RMSE
# 0                 -4.573860  0.716535
# 1                 -3.261067  0.716535
# 2                 -3.258770  0.716535
# 3                 -3.230251  0.716535
# 4                 -3.226611  0.716535
# 5                 -3.215892  0.716535
# 6                 -3.199554  0.716535
# 7                 -3.121986  0.716535
# 8                 -3.066794  0.716535
# 9                 -3.064554  0.716535

# %%
rf = pd.read_csv('../results/random_forest_results.csv', index_col=0).reset_index(drop=True)
rf['predicted_activity(log10)'] = -rf['predicted_activity(log10)']
rf.head(10)
# Out:
#                                                 name  \
# 0                                         NAFAMOSTAT
# 1                                          RWJ-51084
# 2                                          RWJ-56423
# 3                                           CAMOSTAT
# 4  1-[(4S)-4-AMINO-5-(1,3-BENZOTHIAZOL-2-YL)-5-OX...
# 5                                          RWJ-58643
# 6         N-(1-ADAMANTYL)-N'-(4-GUANIDINOBENZYL)UREA
# 7                                  CAMOSTAT-MESILATE
# 8                                             TO-195
# 9                                              GEPON
#
#                                               smiles  \
# 0      NC(N)=Nc1ccc(cc1)C(=O)Oc1cc2ccc(cc2cc1)C(N)=N
# 1  NC(N)=NCCC[C@H](NC(=O)C1CCCC1)C(=O)c1[n]c2cccc...
# 2  CC(=O)N1C[C@H](O)C[C@H]1C(=O)N[C@@H](CCCN=C(N)...
# 3  CN(C)C(=O)COC(=O)Cc1ccc(cc1)OC(=O)c1ccc(cc1)N=...
# 4           NC(=N)NCCC[C@H](N)C(=O)c1[n]c2ccccc2[s]1
# 5  CC(=O)N1C[C@H](O)C[C@H]1C(=O)NC(CCCNC(N)=N)C(=...
# 6      NC(N)=Nc1ccc(CNC(=O)NC23CC4CC(C2)CC(C3)C4)cc1
# 7  CN(C)C(=O)COC(=O)Cc1ccc(cc1)OC(=O)c1ccc(cc1)NC...
# 8  NC(=N)c1cc2ccc(cc2cc1)OC(=O)c1ccc(CNC(=O)CCCC(...
# 9  CC(C)[C@@H](NC(=O)C(NC(=O)[C@@H](CCC(O)=O)NC(=...
#
#    predicted_activity(log10)      RMSE
# 0                  -2.797827  0.590069
# 1                  -2.499190  0.590069
# 2                  -2.365654  0.590069
# 3                  -2.212964  0.590069
# 4                  -1.974841  0.590069
# 5                  -1.959521  0.590069
# 6                  -1.320940  0.590069
# 7                  -1.237724  0.590069
# 8                  -1.235729  0.590069
# 9                  -1.232370  0.590069

# %%
svm = pd.read_csv('../results/svm_screening_results_no_duplicate_names.csv', index_col=0).reset_index(drop=True)
svm['name'] = svm.name.str.upper()
svm.head(10)
# Out:
#      source                          name  pred_value      RMSE
# 0   reframe                    NAFAMOSTAT   -4.573851  0.750939
# 1     broad                   SUBSTANCE-P   -3.270026  0.750939
# 2   reframe                      CAMOSTAT   -3.063672  0.750939
# 3     broad  [SAR9,MET(O2)11]-SUBSTANCE-P   -2.878899  0.750939
# 4  drugbank  SAR9, MET (O2)11-SUBSTANCE P   -2.878899  0.750939
# 5   reframe                     RWJ-58643   -2.231559  0.750939
# 6   reframe           SEPIMOSTAT MESILATE   -2.119949  0.750939
# 7  drugbank                     RWJ-56423   -2.051680  0.750939
# 8     broad                    TELAPREVIR   -2.013527  0.750939
# 9   reframe                   ATECEGATRAN   -1.981752  0.750939

# %%
knn_RMSE = knn['RMSE'][0]
rf_RMSE = rf['RMSE'][0]
svm_RMSE = svm['RMSE'][0]
print(f'Method          RMSE     Weight (1/RMSE)')
print(f'knn            {knn_RMSE: .2f}    {1/knn_RMSE: .2f}')
print(f'random forest  {rf_RMSE: .2f}    {1/rf_RMSE: .2f}')
print(f'svm            {svm_RMSE: .2f}    {1/svm_RMSE: .2f}')
# Out:
# Method          RMSE     Weight (1/RMSE)
# knn             0.72     1.40
# random forest   0.59     1.69
# svm             0.75     1.33

# %%
knn.drop(columns=['source', 'RMSE'], inplace=True)
rf.drop(columns=['smiles', 'RMSE'], inplace=True)
svm.drop(columns=['source', 'RMSE'], inplace=True)

# %%
knn = knn.rename(columns={'predicted_acvalue(log10)': 'knn_acvalue'})
rf = rf.rename(columns={'predicted_activity(log10)': 'random_forest_acvalue'})
svm = svm.rename(columns={'pred_value': 'svm_acvalue'})

# %%
combined = rf.merge(svm, on='name', how='outer').merge(knn, on='name', how='outer')

# %%
combined.head(10)
# Out:
#                                                 name  random_forest_acvalue  \
# 0                                         NAFAMOSTAT              -2.797827
# 1                                          RWJ-51084              -2.499190
# 2                                          RWJ-56423              -2.365654
# 3                                           CAMOSTAT              -2.212964
# 4  1-[(4S)-4-AMINO-5-(1,3-BENZOTHIAZOL-2-YL)-5-OX...              -1.974841
# 5                                          RWJ-58643              -1.959521
# 6         N-(1-ADAMANTYL)-N'-(4-GUANIDINOBENZYL)UREA              -1.320940
# 7                                  CAMOSTAT-MESILATE              -1.237724
# 8                                             TO-195              -1.235729
# 9                                              GEPON              -1.232370
#
#    svm_acvalue  knn_acvalue
# 0    -4.573851    -4.573860
# 1    -1.887822    -3.003530
# 2    -2.051680    -3.215892
# 3    -3.063672          NaN
# 4          NaN    -3.230251
# 5    -2.231559    -2.847431
# 6          NaN          NaN
# 7    -0.694657          NaN
# 8    -0.040993          NaN
# 9          NaN    -0.923724

# %%
acvalue = np.array([combined.knn_acvalue, combined.svm_acvalue, combined.random_forest_acvalue]).T
weights = np.array([1/knn_RMSE, 1/svm_RMSE, 1/rf_RMSE]) * np.ones_like(acvalue)
weights[np.isnan(acvalue)] = 0
combined['combined_acvalue'] = np.nansum(acvalue*weights, axis=1) / np.sum(weights, axis=1)

# %%
combined.sort_values(by='combined_acvalue', inplace=True)
combined.reset_index(drop=True, inplace=True)
combined.to_csv('../results/combined_results.csv')

# %%
pd.set_option('display.max_rows', 50)
combined.head(50)
# Out:
#                                                  name  random_forest_acvalue  \
# 0                                          NAFAMOSTAT              -2.797827
# 1   L-N(OMEGA)-NITROARGININE-(4R)-AMINO-L-PROLINE ...                    NaN
# 2                         INDIUM IN-111 PENTETREOTIDE                    NaN
# 3                                        ETARFOLATIDE                    NaN
# 4                                            CAMOSTAT              -2.212964
# 5   1-[(4S)-4-AMINO-5-(1,3-BENZOTHIAZOL-2-YL)-5-OX...              -1.974841
# 6                                           RWJ-56423              -2.365654
# 7                                           RWJ-51084              -2.499190
# 8                                N,N-DIMETHYLARGININE                    NaN
# 9                                           RWJ-58643              -1.959521
# 10                GUANIDINOETHYLDISULFIDE-BICARBONATE                    NaN
# 11                       [SAR9,MET(O2)11]-SUBSTANCE-P                    NaN
# 12                                       GRAMICIDIN D                    NaN
# 13  4-METHYL-PENTANOIC ACID {1-[4-GUANIDINO-1-(THI...                    NaN
# 14                 4R-FLUORO-N6-ETHANIMIDOYL-L-LYSINE                    NaN
# 15                                SEPIMOSTAT MESILATE                    NaN
# 16                                        MIFAMURTIDE                    NaN
# 17                                         TELAPREVIR                    NaN
# 18                                           U-75799E              -1.156762
# 19                                        SUBSTANCE-P              -1.214972
# 20                                         EXAMORELIN              -1.125477
# 21                                             SP2456                    NaN
# 22                                         DEPREOTIDE              -1.014655
# 23                                         IPAMORELIN              -0.677497
# 24  [[1-[N-HYDROXY-ACETAMIDYL]-3-METHYL-BUTYL]-CAR...                    NaN
# 25                       SAR9, MET (O2)11-SUBSTANCE P              -1.144704
# 26                                          BIO-11006              -0.816413
# 27                                        ORPHANIN-FQ              -0.950890
# 28                               DELTA-2-ALBOMYCIN A1              -1.139417
# 29  3-FORMYL-2-HYDROXY-5-METHYL-HEXANOIC ACID HYDR...                    NaN
# 30                                   AERUGINOSIN 98-B              -1.156905
# 31                                           CTS21166              -0.538498
# 32                                        MITOGUAZONE                    NaN
# 33                                           BOMBESIN              -1.129983
# 34                                        GONADORELIN              -0.980204
# 35                                         BOCEPREVIR                    NaN
# 36                                        THYMOPENTIN              -0.307772
# 37                                         COTADUTIDE              -0.463477
# 38                                       ANTAGONIST-G              -0.890731
# 39                                        SEMAGLUTIDE              -0.433194
# 40                                TALACTOFERRIN ALPHA              -0.397284
# 41  2-(2-HYDROXY-PHENYL)-3H-BENZOIMIDAZOLE-5-CARBO...                    NaN
# 42                                       TASPOGLUTIDE              -0.343554
# 43                                  GOSERELIN-ACETATE              -1.044103
# 44                                          FK-33-824              -0.582841
# 45                                           ORLISTAT                    NaN
# 46                                         CIBINETIDE              -0.911497
# 47                                        FELYPRESSIN                    NaN
# 48                                        VASOPRESSIN              -0.944246
# 49                                        PLECANATIDE              -0.109815
#
#     svm_acvalue  knn_acvalue  combined_acvalue
# 0     -4.573851    -4.573860         -3.893197
# 1           NaN    -3.226611         -3.226611
# 2           NaN    -2.905743         -2.905743
# 3           NaN    -2.633206         -2.633206
# 4     -3.063672          NaN         -2.587292
# 5           NaN    -3.230251         -2.541791
# 6     -2.051680    -3.215892         -2.539442
# 7     -1.887822    -3.003530         -2.474252
# 8           NaN    -2.327946         -2.327946
# 9     -2.231559    -2.847431         -2.321674
# 10          NaN    -2.316315         -2.316315
# 11    -2.878899    -1.672230         -2.261420
# 12          NaN    -2.214222         -2.214222
# 13          NaN    -2.207485         -2.207485
# 14          NaN    -2.165486         -2.165486
# 15    -2.119949          NaN         -2.119949
# 16          NaN    -2.072270         -2.072270
# 17    -2.013527          NaN         -2.013527
# 18          NaN    -2.929955         -1.957545
# 19    -3.270026    -1.560627         -1.942935
# 20          NaN    -2.927515         -1.939286
# 21          NaN    -1.936138         -1.936138
# 22          NaN    -2.937208         -1.882890
# 23          NaN    -3.258770         -1.843213
# 24          NaN    -1.836634         -1.836634
# 25    -2.878899    -1.672230         -1.833441
# 26          NaN    -3.066794         -1.832697
# 27          NaN    -2.892716         -1.827829
# 28          NaN    -2.626270         -1.810888
# 29          NaN    -1.806040         -1.806040
# 30          NaN    -2.555776         -1.788642
# 31          NaN    -3.261067         -1.768025
# 32          NaN    -1.728246         -1.728246
# 33          NaN    -2.260552         -1.640554
# 34    -1.594884    -2.406312         -1.615401
# 35    -1.608306          NaN         -1.608306
# 36          NaN    -3.121986         -1.578686
# 37          NaN    -2.811584         -1.523895
# 38    -1.588432    -2.211524         -1.517691
# 39          NaN    -2.811845         -1.507406
# 40          NaN    -2.841080         -1.500915
# 41    -1.497848          NaN         -1.497848
# 42          NaN    -2.899353         -1.497766
# 43    -1.312182    -2.220121         -1.495992
# 44          NaN    -2.586420         -1.487668
# 45          NaN    -1.483744         -1.483744
# 46          NaN    -2.175157         -1.482172
# 47    -1.469064    -1.490229         -1.479894
# 48    -1.845739    -1.718697         -1.460149
# 49          NaN    -3.064554         -1.444190
